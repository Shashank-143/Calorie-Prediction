# %% [markdown]
# # Importing libraries & dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.preprocessing import StandardScaler, RobustScaler, QuantileTransformer
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import PolynomialFeatures
from sklearn.feature_selection import SelectKBest, f_regression, RFE
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import xgboost as xgb
import lightgbm as lgb
from sklearn.ensemble import VotingRegressor, StackingRegressor
from sklearn.preprocessing import PowerTransformer
import warnings
warnings.filterwarnings("ignore")

# %%
# Set random seed for reproducibility
SEED = 42
np.random.seed(SEED)

# %%
def rmsle(y_true, y_pred):
    """Calculate Root Mean Squared Logarithmic Error"""
    # Ensure no negative predictions
    y_pred = np.maximum(y_pred, 0)
    y_true = np.maximum(y_true, 0)
    
    # Add small constant to handle zeros
    epsilon = 1e-15
    y_true_log = np.log1p(y_true + epsilon)
    y_pred_log = np.log1p(y_pred + epsilon)
    
    return np.sqrt(mean_squared_error(y_true_log, y_pred_log))

# %%
# Load data
train_df = pd.read_csv('../data/train.csv').drop(columns='id')
test_df = pd.read_csv('../data/test.csv')

# %%
print(f'Training data shape: {train_df.shape}')
print(f'Test data shape: {test_df.shape}')
# Out:
# Training data shape: (750000, 8)
# Test data shape: (250000, 8)

# %%
# Remove duplicates
train_df.drop_duplicates(inplace=True)
print(f'Training data shape after removing duplicates: {train_df.shape}')
# Out:
# Training data shape after removing duplicates: (747159, 8)

# %% [markdown]
# # Enhanced Data Preprocessing

# %%
def advanced_outlier_handling(df, columns, method='isolation_forest'):
    """Advanced outlier detection and handling"""
    from sklearn.ensemble import IsolationForest
    
    df_processed = df.copy()
    
    if method == 'isolation_forest':
        # Use Isolation Forest for multivariate outlier detection
        iso_forest = IsolationForest(contamination=0.05, random_state=SEED)
        outlier_labels = iso_forest.fit_predict(df[columns])
        
        # Keep only inliers (-1 indicates outliers, 1 indicates inliers)
        df_processed = df_processed[outlier_labels == 1]
        print(f"Removed {sum(outlier_labels == -1)} outliers using Isolation Forest")
    
    elif method == 'iqr_clip':
        # Traditional IQR method with clipping
        for col in columns:
            Q1 = df[col].quantile(0.25)
            Q3 = df[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            df_processed[col] = df_processed[col].clip(lower=lower_bound, upper=upper_bound)
    
    return df_processed

# %%
def advanced_feature_engineering(df, has_target=True):
    """Create advanced engineered features"""
    df_eng = df.copy()
    
    df_eng['BMI'] = df_eng['Weight'] / (df_eng['Height'] / 100) ** 2
    df_eng['BMI_Category'] = pd.cut(df_eng['BMI'], 
                                   bins=[0, 18.5, 25, 30, float('inf')], 
                                   labels=['Underweight', 'Normal', 'Overweight', 'Obese'])
    
    
    df_eng['Age_Group'] = pd.cut(df_eng['Age'], 
                                bins=[0, 25, 35, 45, 55, float('inf')], 
                                labels=['Young', 'Adult', 'Middle_Age', 'Senior', 'Elderly'])
    
    
    male_mask = df_eng['Sex'] == 'male'
    female_mask = df_eng['Sex'] == 'female'
    
    df_eng['BMR'] = 0
    df_eng.loc[male_mask, 'BMR'] = (88.362 + 13.397 * df_eng.loc[male_mask, 'Weight'] + 
                                   4.799 * df_eng.loc[male_mask, 'Height'] - 
                                   5.677 * df_eng.loc[male_mask, 'Age'])
    df_eng.loc[female_mask, 'BMR'] = (447.593 + 9.247 * df_eng.loc[female_mask, 'Weight'] + 
                                     3.098 * df_eng.loc[female_mask, 'Height'] - 
                                     4.330 * df_eng.loc[female_mask, 'Age'])
    
    # Heart rate zones
    max_hr = 220 - df_eng['Age']
    df_eng['HR_Reserve'] = max_hr - df_eng['Heart_Rate']
    df_eng['HR_Intensity'] = df_eng['Heart_Rate'] / max_hr
    
    # Exercise intensity categories
    df_eng['Exercise_Intensity'] = pd.cut(df_eng['HR_Intensity'], 
                                         bins=[0, 0.5, 0.7, 0.85, 1.0], 
                                         labels=['Light', 'Moderate', 'Vigorous', 'Maximum'])
    
    # Only create Calories_Per_Minute for training data (which has Calories column)
    if has_target and 'Calories' in df_eng.columns:
        df_eng['Calories_Per_Minute'] = df_eng['Calories'] / df_eng['Duration']
    
    # Weight to height ratio
    df_eng['Weight_Height_Ratio'] = df_eng['Weight'] / df_eng['Height']
    
    # Temperature difference from normal body temp
    df_eng['Temp_Deviation'] = abs(df_eng['Body_Temp'] - 37.0)
    
    # Interaction features
    df_eng['Weight_Duration'] = df_eng['Weight'] * df_eng['Duration']
    df_eng['HR_Duration'] = df_eng['Heart_Rate'] * df_eng['Duration']
    df_eng['BMI_Duration'] = df_eng['BMI'] * df_eng['Duration']
    df_eng['Age_Weight'] = df_eng['Age'] * df_eng['Weight']
    df_eng['BMR_Duration'] = df_eng['BMR'] * df_eng['Duration']
    
    # Polynomial features for key variables
    df_eng['Weight_Squared'] = df_eng['Weight'] ** 2
    df_eng['Duration_Squared'] = df_eng['Duration'] ** 2
    df_eng['HR_Squared'] = df_eng['Heart_Rate'] ** 2
    df_eng['BMI_Squared'] = df_eng['BMI'] ** 2
    
    # Log transformations for skewed features
    df_eng['Log_Weight'] = np.log1p(df_eng['Weight'])
    df_eng['Log_Duration'] = np.log1p(df_eng['Duration'])
    
    return df_eng

# %%
def advanced_preprocessing_pipeline(df, target_column=None, is_training=True):
    """Complete preprocessing pipeline"""
    df_processed = df.copy()
    
    # Advanced feature engineering - pass has_target parameter
    df_processed = advanced_feature_engineering(df_processed, has_target=is_training)
    
    # Handle outliers only for training data
    if is_training and target_column and target_column in df_processed.columns:
        numerical_cols = ['Age', 'Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp', 'BMI']
        df_processed = advanced_outlier_handling(df_processed, numerical_cols + [target_column], method='iqr_clip')
    
    # Advanced target transformation for training data
    if is_training and target_column and target_column in df_processed.columns:
        # Apply Box-Cox transformation to target
        from scipy.stats import boxcox
        target_values = df_processed[target_column].values
        
        # Ensure all values are positive for Box-Cox
        if np.any(target_values <= 0):
            target_values = target_values + 1
        
        try:
            transformed_target, lambda_param = boxcox(target_values)
            df_processed[f'{target_column}_boxcox'] = transformed_target
            print(f"Applied Box-Cox transformation with lambda: {lambda_param:.4f}")
        except:
            print("Box-Cox transformation failed, using log transformation")
            df_processed[f'{target_column}_boxcox'] = np.log1p(target_values)
    
    # One-hot encoding for categorical variables
    categorical_cols = ['Sex', 'BMI_Category', 'Age_Group', 'Exercise_Intensity']
    df_processed = pd.get_dummies(df_processed, columns=categorical_cols, drop_first=True)
    
    # Fill any missing values
    numeric_columns = df_processed.select_dtypes(include=[np.number]).columns
    df_processed[numeric_columns] = df_processed[numeric_columns].fillna(df_processed[numeric_columns].median())
    
    return df_processed

# %%
# Apply preprocessing
print("Preprocessing training data...")
train_processed = advanced_preprocessing_pipeline(train_df, 'Calories', is_training=True)

print("Preprocessing test data...")
test_processed = advanced_preprocessing_pipeline(test_df, is_training=False)
# Out:
# Preprocessing training data...
# Applied Box-Cox transformation with lambda: 0.4398
# Preprocessing test data...

# %%
# Ensure same columns in train and test (excluding target columns)
target_cols = ['Calories', 'Calories_boxcox', 'Calories_Per_Minute']
train_feature_cols = [col for col in train_processed.columns if col not in target_cols]
test_cols = list(test_processed.columns)

# %%
# Add missing columns to test set
for col in train_feature_cols:
    if col not in test_cols:
        test_processed[col] = 0
        print(f"Added missing column to test set: {col}")

# Remove extra columns from test set that aren't in training features
for col in test_cols:
    if col not in train_feature_cols:
        test_processed = test_processed.drop(columns=[col])
        print(f"Removed extra column from test set: {col}")

# Reorder columns to match training features
test_processed = test_processed.reindex(columns=train_feature_cols, fill_value=0)

print(f"Training data shape after preprocessing: {train_processed.shape}")
print(f"Test data shape after preprocessing: {test_processed.shape}")
print(f"Training feature columns: {len(train_feature_cols)}")
print(f"Test feature columns: {len(test_processed.columns)}")
# Out:
# Removed extra column from test set: id
# Training data shape after preprocessing: (747159, 37)
# Test data shape after preprocessing: (250000, 34)
# Training feature columns: 34
# Test feature columns: 34

# %%
# Prepare features and target
X = train_processed[train_feature_cols]
y = train_processed['Calories']

print(f"Features shape: {X.shape}")
print(f"Target shape: {y.shape}")
# Out:
# Features shape: (747159, 34)
# Target shape: (747159,)

# %%
scaler = RobustScaler()  # More robust to outliers than StandardScaler
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns, index=X.index)

# %%
def create_stratified_split(X, y, test_size=0.2, random_state=SEED):
    """Create stratified split based on target quantiles"""
    y_binned = pd.qcut(y, q=5, labels=False, duplicates='drop')
    return train_test_split(X, y, test_size=test_size, random_state=random_state, stratify=y_binned)

X_train, X_val, y_train, y_val = create_stratified_split(X_scaled, y, test_size=0.2)

# %%
def get_advanced_models():
    """Get optimized model configurations"""
    models = {
        'XGBoost': xgb.XGBRegressor(
            n_estimators=1000,
            learning_rate=0.05,
            max_depth=6,
            subsample=0.8,
            colsample_bytree=0.8,
            reg_alpha=0.1,
            reg_lambda=1,
            random_state=SEED,
            early_stopping_rounds=50,
            eval_metric='rmse'
        ),
        'LightGBM': lgb.LGBMRegressor(
            n_estimators=1000,
            learning_rate=0.05,
            max_depth=6,
            subsample=0.8,
            colsample_bytree=0.8,
            reg_alpha=0.1,
            reg_lambda=1,
            random_state=SEED,
            early_stopping_rounds=50,
            metric='rmse'
        ),
        'Random_Forest': RandomForestRegressor(
            n_estimators=300,
            max_depth=15,
            min_samples_split=5,
            min_samples_leaf=2,
            max_features='sqrt',
            random_state=SEED,
            n_jobs=-1
        ),
        'Extra_Trees': ExtraTreesRegressor(
            n_estimators=300,
            max_depth=15,
            min_samples_split=5,
            min_samples_leaf=2,
            max_features='sqrt',
            random_state=SEED,
            n_jobs=-1
        ),
        'Gradient_Boosting': GradientBoostingRegressor(
            n_estimators=500,
            learning_rate=0.05,
            max_depth=6,
            subsample=0.8,
            random_state=SEED
        )
    }
    return models

# %%
# Cross-validation with RMSLE
def cross_validate_rmsle(model, X, y, cv=5):
    """Perform cross-validation with RMSLE scoring"""
    kfold = KFold(n_splits=cv, shuffle=True, random_state=SEED)
    rmsle_scores = []
    
    for train_idx, val_idx in kfold.split(X):
        X_train_cv, X_val_cv = X.iloc[train_idx], X.iloc[val_idx]
        y_train_cv, y_val_cv = y.iloc[train_idx], y.iloc[val_idx]
        
        # Fit model
        if hasattr(model, 'early_stopping_rounds'):
            model.fit(X_train_cv, y_train_cv, 
                     eval_set=[(X_val_cv, y_val_cv)])
            
        else:
            model.fit(X_train_cv, y_train_cv)
        
        # Predict and calculate RMSLE
        y_pred = model.predict(X_val_cv)
        rmsle_score = rmsle(y_val_cv, y_pred)
        rmsle_scores.append(rmsle_score)
    
    return np.mean(rmsle_scores), np.std(rmsle_scores)

# %%
# Train and evaluate models
models = get_advanced_models()
model_results = {}

print("Training and evaluating models...")
for name, model in models.items():
    print(f"\nTraining {name}...")
    
    # Cross-validation
    cv_mean, cv_std = cross_validate_rmsle(model, X_train, y_train, cv=5)
    
    # Train on full training set
    if hasattr(model, 'early_stopping_rounds'):
        model.fit(X_train, y_train, 
                 eval_set=[(X_val, y_val)])
    else:
        model.fit(X_train, y_train)
    
    # Validation predictions
    y_pred = model.predict(X_val)
    val_rmsle = rmsle(y_val, y_pred)
    
    model_results[name] = {
        'model': model,
        'cv_mean': cv_mean,
        'cv_std': cv_std,
        'val_rmsle': val_rmsle
    }
    
    print(f"CV RMSLE: {cv_mean:.5f} (+/- {cv_std:.5f})")
    print(f"Validation RMSLE: {val_rmsle:.5f}")
# Out:
# Training and evaluating models...
#
# Training XGBoost...
# [0]	validation_0-rmse:59.36107
# [1]	validation_0-rmse:56.44386
# [2]	validation_0-rmse:53.67394
# [3]	validation_0-rmse:51.05760
# [4]	validation_0-rmse:48.55221
# [5]	validation_0-rmse:46.17618
# [6]	validation_0-rmse:43.93320
# [7]	validation_0-rmse:41.78926
# [8]	validation_0-rmse:39.75017
# [9]	validation_0-rmse:37.83283
# [10]	validation_0-rmse:35.99422
# [11]	validation_0-rmse:34.26038
# [12]	validation_0-rmse:32.60376
# [13]	validation_0-rmse:31.03101
# [14]	validation_0-rmse:29.53682
# [15]	validation_0-rmse:28.11950
# [16]	validation_0-rmse:26.77038
# [17]	validation_0-rmse:25.50196
# [18]	validation_0-rmse:24.29029
# [19]	validation_0-rmse:23.13657
# [20]	validation_0-rmse:22.04100
# [21]	validation_0-rmse:21.00102
# [22]	validation_0-rmse:20.01524
# [23]	validation_0-rmse:19.08382
# [24]	validation_0-rmse:18.20243
# [25]	validation_0-rmse:17.37126
# [26]	validation_0-rmse:16.57359
# [27]	validation_0-rmse:15.82678
# [28]	validation_0-rmse:15.11017
# [29]	validation_0-rmse:14.43022
# [30]	validation_0-rmse:13.79131
# [31]	validation_0-rmse:13.18364
# [32]	validation_0-rmse:12.61441
# [33]	validation_0-rmse:12.06800
# [34]	validation_0-rmse:11.55746
# [35]	validation_0-rmse:11.07040
# [36]	validation_0-rmse:10.60821
# [37]	validation_0-rmse:10.17596
# [38]	validation_0-rmse:9.76494
# [39]	validation_0-rmse:9.37943
# [40]	validation_0-rmse:9.01741
# [41]	validation_0-rmse:8.67299
# [42]	validation_0-rmse:8.34856
# [43]	validation_0-rmse:8.04302
# [44]	validation_0-rmse:7.75697
# [45]	validation_0-rmse:7.48705
# [46]	validation_0-rmse:7.23148
# [47]	validation_0-rmse:6.99196
# [48]	validation_0-rmse:6.76873
# [49]	validation_0-rmse:6.55858
# [50]	validation_0-rmse:6.36253
# [51]	validation_0-rmse:6.17894
# [52]	validation_0-rmse:6.00479
# [53]	validation_0-rmse:5.84343
# [54]	validation_0-rmse:5.69199
# [55]	validation_0-rmse:5.55240
# [56]	validation_0-rmse:5.42098
# [57]	validation_0-rmse:5.29764
# [58]	validation_0-rmse:5.18523
# [59]	validation_0-rmse:5.08109
# [60]	validation_0-rmse:4.98215
# [61]	validation_0-rmse:4.88979
# [62]	validation_0-rmse:4.80460
# [63]	validation_0-rmse:4.72737
# [64]	validation_0-rmse:4.65668
# [65]	validation_0-rmse:4.59092
# [66]	validation_0-rmse:4.52682
# [67]	validation_0-rmse:4.47031
# [68]	validation_0-rmse:4.41602
# [69]	validation_0-rmse:4.36516
# [70]	validation_0-rmse:4.32093
# [71]	validation_0-rmse:4.27842
# [72]	validation_0-rmse:4.24027
# [73]	validation_0-rmse:4.20426
# [74]	validation_0-rmse:4.16857
# [75]	validation_0-rmse:4.13926
# [76]	validation_0-rmse:4.11151
# [77]	validation_0-rmse:4.08490
# [78]	validation_0-rmse:4.06198
# [79]	validation_0-rmse:4.03782
# [80]	validation_0-rmse:4.01812
# [81]	validation_0-rmse:3.99557
# [82]	validation_0-rmse:3.97807
# [83]	validation_0-rmse:3.95776
# [84]	validation_0-rmse:3.94205
# [85]	validation_0-rmse:3.92602
# [86]	validation_0-rmse:3.91323
# [87]	validation_0-rmse:3.90028
# [88]	validation_0-rmse:3.88723
# [89]	validation_0-rmse:3.87709
# [90]	validation_0-rmse:3.86645
# [91]	validation_0-rmse:3.85560
# [92]	validation_0-rmse:3.84541
# [93]	validation_0-rmse:3.83655
# [94]	validation_0-rmse:3.82964
# [95]	validation_0-rmse:3.82289
# [96]	validation_0-rmse:3.81583
# [97]	validation_0-rmse:3.80938
# [98]	validation_0-rmse:3.80146
# [99]	validation_0-rmse:3.79770
# [100]	validation_0-rmse:3.79238
# [101]	validation_0-rmse:3.78707
# [102]	validation_0-rmse:3.78296
# [103]	validation_0-rmse:3.77774
# [104]	validation_0-rmse:3.77303
# [105]	validation_0-rmse:3.76984
# [106]	validation_0-rmse:3.76621
# [107]	validation_0-rmse:3.76246
# [108]	validation_0-rmse:3.75938
# [109]	validation_0-rmse:3.75663
# [110]	validation_0-rmse:3.75242
# [111]	validation_0-rmse:3.74868
# [112]	validation_0-rmse:3.74711
# [113]	validation_0-rmse:3.74512
# [114]	validation_0-rmse:3.74281
# [115]	validation_0-rmse:3.74050
# [116]	validation_0-rmse:3.73886
# [117]	validation_0-rmse:3.73674
# [118]	validation_0-rmse:3.73448
# [119]	validation_0-rmse:3.73233
# [120]	validation_0-rmse:3.72852
# [121]	validation_0-rmse:3.72780
# [122]	validation_0-rmse:3.72747
# [123]	validation_0-rmse:3.72534
# [124]	validation_0-rmse:3.72041
# [125]	validation_0-rmse:3.71626
# [126]	validation_0-rmse:3.71498
# [127]	validation_0-rmse:3.71303
# [128]	validation_0-rmse:3.71205
# [129]	validation_0-rmse:3.71047
# [130]	validation_0-rmse:3.70826
# [131]	validation_0-rmse:3.70768
# [132]	validation_0-rmse:3.70606
# [133]	validation_0-rmse:3.70524
# [134]	validation_0-rmse:3.70441
# [135]	validation_0-rmse:3.70065
# [136]	validation_0-rmse:3.69936
# [137]	validation_0-rmse:3.69858
# [138]	validation_0-rmse:3.69799
# [139]	validation_0-rmse:3.69777
# [140]	validation_0-rmse:3.69714
# [141]	validation_0-rmse:3.69512
# [142]	validation_0-rmse:3.69421
# [143]	validation_0-rmse:3.69372
# [144]	validation_0-rmse:3.69324
# [145]	validation_0-rmse:3.69298
# [146]	validation_0-rmse:3.69172
# [147]	validation_0-rmse:3.69028
# [148]	validation_0-rmse:3.69005
# [149]	validation_0-rmse:3.68948
# [150]	validation_0-rmse:3.68870
# [151]	validation_0-rmse:3.68826
# [152]	validation_0-rmse:3.68761
# [153]	validation_0-rmse:3.68655
# [154]	validation_0-rmse:3.68594
# [155]	validation_0-rmse:3.68468
# [156]	validation_0-rmse:3.68418
# [157]	validation_0-rmse:3.68258
# [158]	validation_0-rmse:3.68242
# [159]	validation_0-rmse:3.68307
# [160]	validation_0-rmse:3.68254
# [161]	validation_0-rmse:3.68219
# [162]	validation_0-rmse:3.68183
# [163]	validation_0-rmse:3.68151
# [164]	validation_0-rmse:3.68114
# [165]	validation_0-rmse:3.68041
# [166]	validation_0-rmse:3.68025
# [167]	validation_0-rmse:3.67993
# [168]	validation_0-rmse:3.67966
# [169]	validation_0-rmse:3.67908
# [170]	validation_0-rmse:3.67850
# [171]	validation_0-rmse:3.67754
# [172]	validation_0-rmse:3.67723
# [173]	validation_0-rmse:3.67671
# [174]	validation_0-rmse:3.67620
# [175]	validation_0-rmse:3.67562
# [176]	validation_0-rmse:3.67524
# [177]	validation_0-rmse:3.67380
# [178]	validation_0-rmse:3.67361
# [179]	validation_0-rmse:3.67309
# [180]	validation_0-rmse:3.67305
# [181]	validation_0-rmse:3.67310
# [182]	validation_0-rmse:3.67284
# [183]	validation_0-rmse:3.67284
# [184]	validation_0-rmse:3.67266
# [185]	validation_0-rmse:3.67196
# [186]	validation_0-rmse:3.67186
# [187]	validation_0-rmse:3.67177
# [188]	validation_0-rmse:3.67117
# [189]	validation_0-rmse:3.67120
# [190]	validation_0-rmse:3.67111
# [191]	validation_0-rmse:3.67053
# [192]	validation_0-rmse:3.67051
# [193]	validation_0-rmse:3.67010
# [194]	validation_0-rmse:3.66944
# [195]	validation_0-rmse:3.66951
# [196]	validation_0-rmse:3.66860
# [197]	validation_0-rmse:3.66779
# [198]	validation_0-rmse:3.66709
# [199]	validation_0-rmse:3.66684
# [200]	validation_0-rmse:3.66675
# [201]	validation_0-rmse:3.66636
# [202]	validation_0-rmse:3.66623
# [203]	validation_0-rmse:3.66637
# [204]	validation_0-rmse:3.66560
# [205]	validation_0-rmse:3.66539
# [206]	validation_0-rmse:3.66521
# [207]	validation_0-rmse:3.66512
# [208]	validation_0-rmse:3.66472
# [209]	validation_0-rmse:3.66408
# [210]	validation_0-rmse:3.66368
# [211]	validation_0-rmse:3.66322
# [212]	validation_0-rmse:3.66295
# [213]	validation_0-rmse:3.66263
# [214]	validation_0-rmse:3.66223
# [215]	validation_0-rmse:3.66229
# [216]	validation_0-rmse:3.66115
# [217]	validation_0-rmse:3.66074
# [218]	validation_0-rmse:3.66026
# [219]	validation_0-rmse:3.66006
# [220]	validation_0-rmse:3.65998
# [221]	validation_0-rmse:3.65993
# [222]	validation_0-rmse:3.65989
# [223]	validation_0-rmse:3.66008
# [224]	validation_0-rmse:3.65995
# [225]	validation_0-rmse:3.65985
# [226]	validation_0-rmse:3.65960
# [227]	validation_0-rmse:3.65921
# [228]	validation_0-rmse:3.65894
# [229]	validation_0-rmse:3.65873
# [230]	validation_0-rmse:3.65839
# [231]	validation_0-rmse:3.65757
# [232]	validation_0-rmse:3.65710
# [233]	validation_0-rmse:3.65697
# [234]	validation_0-rmse:3.65691
# [235]	validation_0-rmse:3.65692
# [236]	validation_0-rmse:3.65694
# [237]	validation_0-rmse:3.65654
# [238]	validation_0-rmse:3.65659
# [239]	validation_0-rmse:3.65646
# [240]	validation_0-rmse:3.65623
# [241]	validation_0-rmse:3.65598
# [242]	validation_0-rmse:3.65570
# [243]	validation_0-rmse:3.65581
# [244]	validation_0-rmse:3.65562
# [245]	validation_0-rmse:3.65515
# [246]	validation_0-rmse:3.65484
# [247]	validation_0-rmse:3.65494
# [248]	validation_0-rmse:3.65423
# [249]	validation_0-rmse:3.65344
# [250]	validation_0-rmse:3.65334
# [251]	validation_0-rmse:3.65334
# [252]	validation_0-rmse:3.65318
# [253]	validation_0-rmse:3.65288
# [254]	validation_0-rmse:3.65248
# [255]	validation_0-rmse:3.65251
# [256]	validation_0-rmse:3.65261
# [257]	validation_0-rmse:3.65289
# [258]	validation_0-rmse:3.65240
# [259]	validation_0-rmse:3.65132
# [260]	validation_0-rmse:3.65135
# [261]	validation_0-rmse:3.65084
# [262]	validation_0-rmse:3.65042
# [263]	validation_0-rmse:3.65032
# [264]	validation_0-rmse:3.64991
# [265]	validation_0-rmse:3.64938
# [266]	validation_0-rmse:3.64949
# [267]	validation_0-rmse:3.64937
# [268]	validation_0-rmse:3.64934
# [269]	validation_0-rmse:3.64942
# [270]	validation_0-rmse:3.64931
# [271]	validation_0-rmse:3.64877
# [272]	validation_0-rmse:3.64922
# [273]	validation_0-rmse:3.64921
# [274]	validation_0-rmse:3.64920
# [275]	validation_0-rmse:3.64858
# [276]	validation_0-rmse:3.64843
# [277]	validation_0-rmse:3.64853
# [278]	validation_0-rmse:3.64862
# [279]	validation_0-rmse:3.64844
# [280]	validation_0-rmse:3.64854
# [281]	validation_0-rmse:3.64818
# [282]	validation_0-rmse:3.64896
# [283]	validation_0-rmse:3.64790
# [284]	validation_0-rmse:3.64778
# [285]	validation_0-rmse:3.64788
# [286]	validation_0-rmse:3.64763
# [287]	validation_0-rmse:3.64761
# [288]	validation_0-rmse:3.64768
# [289]	validation_0-rmse:3.64743
# [290]	validation_0-rmse:3.64725
# [291]	validation_0-rmse:3.64676
# [292]	validation_0-rmse:3.64668
# [293]	validation_0-rmse:3.64642
# [294]	validation_0-rmse:3.64628
# [295]	validation_0-rmse:3.64565
# [296]	validation_0-rmse:3.64564
# [297]	validation_0-rmse:3.64557
# [298]	validation_0-rmse:3.64504
# [299]	validation_0-rmse:3.64476
# [300]	validation_0-rmse:3.64464
# [301]	validation_0-rmse:3.64474
# [302]	validation_0-rmse:3.64510
# [303]	validation_0-rmse:3.64459
# [304]	validation_0-rmse:3.64439
# [305]	validation_0-rmse:3.64412
# [306]	validation_0-rmse:3.64427
# [307]	validation_0-rmse:3.64401
# [308]	validation_0-rmse:3.64393
# [309]	validation_0-rmse:3.64352
# [310]	validation_0-rmse:3.64337
# [311]	validation_0-rmse:3.64328
# [312]	validation_0-rmse:3.64296
# [313]	validation_0-rmse:3.64296
# [314]	validation_0-rmse:3.64296
# [315]	validation_0-rmse:3.64273
# [316]	validation_0-rmse:3.64271
# [317]	validation_0-rmse:3.64263
# [318]	validation_0-rmse:3.64291
# [319]	validation_0-rmse:3.64286
# [320]	validation_0-rmse:3.64300
# [321]	validation_0-rmse:3.64288
# [322]	validation_0-rmse:3.64276
# [323]	validation_0-rmse:3.64294
# [324]	validation_0-rmse:3.64267
# [325]	validation_0-rmse:3.64258
# [326]	validation_0-rmse:3.64240
# [327]	validation_0-rmse:3.64238
# [328]	validation_0-rmse:3.64207
# [329]	validation_0-rmse:3.64171
# [330]	validation_0-rmse:3.64156
# [331]	validation_0-rmse:3.64117
# [332]	validation_0-rmse:3.64122
# [333]	validation_0-rmse:3.64148
# [334]	validation_0-rmse:3.64118
# [335]	validation_0-rmse:3.64113
# [336]	validation_0-rmse:3.64121
# [337]	validation_0-rmse:3.64085
# [338]	validation_0-rmse:3.64063
# [339]	validation_0-rmse:3.64078
# [340]	validation_0-rmse:3.64031
# [341]	validation_0-rmse:3.64059
# [342]	validation_0-rmse:3.64063
# [343]	validation_0-rmse:3.64053
# [344]	validation_0-rmse:3.64030
# [345]	validation_0-rmse:3.64027
# [346]	validation_0-rmse:3.64023
# [347]	validation_0-rmse:3.63999
# [348]	validation_0-rmse:3.63992
# [349]	validation_0-rmse:3.64001
# [350]	validation_0-rmse:3.64013
# [351]	validation_0-rmse:3.64009
# [352]	validation_0-rmse:3.64005
# [353]	validation_0-rmse:3.63951
# [354]	validation_0-rmse:3.63957
# [355]	validation_0-rmse:3.63972
# [356]	validation_0-rmse:3.63972
# [357]	validation_0-rmse:3.63963
# [358]	validation_0-rmse:3.63965
# [359]	validation_0-rmse:3.63966
# [360]	validation_0-rmse:3.63952
# [361]	validation_0-rmse:3.63883
# [362]	validation_0-rmse:3.63876
# [363]	validation_0-rmse:3.63877
# [364]	validation_0-rmse:3.63837
# [365]	validation_0-rmse:3.63806
# [366]	validation_0-rmse:3.63810
# [367]	validation_0-rmse:3.63813
# [368]	validation_0-rmse:3.63810
# [369]	validation_0-rmse:3.63786
# [370]	validation_0-rmse:3.63807
# [371]	validation_0-rmse:3.63812
# [372]	validation_0-rmse:3.63804
# [373]	validation_0-rmse:3.63798
# [374]	validation_0-rmse:3.63796
# [375]	validation_0-rmse:3.63787
# [376]	validation_0-rmse:3.63781
# [377]	validation_0-rmse:3.63781
# [378]	validation_0-rmse:3.63772
# [379]	validation_0-rmse:3.63765
# [380]	validation_0-rmse:3.63765
# [381]	validation_0-rmse:3.63753
# [382]	validation_0-rmse:3.63717
# [383]	validation_0-rmse:3.63719
# [384]	validation_0-rmse:3.63665
# [385]	validation_0-rmse:3.63649
# [386]	validation_0-rmse:3.63651
# [387]	validation_0-rmse:3.63639
# [388]	validation_0-rmse:3.63624
# [389]	validation_0-rmse:3.63593
# [390]	validation_0-rmse:3.63574
# [391]	validation_0-rmse:3.63560
# [392]	validation_0-rmse:3.63549
# [393]	validation_0-rmse:3.63565
# [394]	validation_0-rmse:3.63511
# [395]	validation_0-rmse:3.63492
# [396]	validation_0-rmse:3.63497
# [397]	validation_0-rmse:3.63485
# [398]	validation_0-rmse:3.63403
# [399]	validation_0-rmse:3.63401
# [400]	validation_0-rmse:3.63410
# [401]	validation_0-rmse:3.63393
# [402]	validation_0-rmse:3.63398
# [403]	validation_0-rmse:3.63369
# [404]	validation_0-rmse:3.63299
# [405]	validation_0-rmse:3.63294
# [406]	validation_0-rmse:3.63286
# [407]	validation_0-rmse:3.63293
# [408]	validation_0-rmse:3.63291
# [409]	validation_0-rmse:3.63302
# [410]	validation_0-rmse:3.63325
# [411]	validation_0-rmse:3.63295
# [412]	validation_0-rmse:3.63298
# [413]	validation_0-rmse:3.63293
# [414]	validation_0-rmse:3.63274
# [415]	validation_0-rmse:3.63280
# [416]	validation_0-rmse:3.63283
# [417]	validation_0-rmse:3.63288
# [418]	validation_0-rmse:3.63276
# [419]	validation_0-rmse:3.63275
# [420]	validation_0-rmse:3.63247
# [421]	validation_0-rmse:3.63246
# [422]	validation_0-rmse:3.63257
# [423]	validation_0-rmse:3.63254
# [424]	validation_0-rmse:3.63250
# [425]	validation_0-rmse:3.63234
# [426]	validation_0-rmse:3.63181
# [427]	validation_0-rmse:3.63175
# [428]	validation_0-rmse:3.63188
# [429]	validation_0-rmse:3.63179
# [430]	validation_0-rmse:3.63163
# [431]	validation_0-rmse:3.63159
# [432]	validation_0-rmse:3.63161
# [433]	validation_0-rmse:3.63157
# [434]	validation_0-rmse:3.63121
# [435]	validation_0-rmse:3.63104
# [436]	validation_0-rmse:3.63106
# [437]	validation_0-rmse:3.63117
# [438]	validation_0-rmse:3.63119
# [439]	validation_0-rmse:3.63130
# [440]	validation_0-rmse:3.63131
# [441]	validation_0-rmse:3.63138
# [442]	validation_0-rmse:3.63137
# [443]	validation_0-rmse:3.63144
# [444]	validation_0-rmse:3.63150
# [445]	validation_0-rmse:3.63156
# [446]	validation_0-rmse:3.63147
# [447]	validation_0-rmse:3.63145
# [448]	validation_0-rmse:3.63134
# [449]	validation_0-rmse:3.63136
# [450]	validation_0-rmse:3.63130
# [451]	validation_0-rmse:3.63137
# [452]	validation_0-rmse:3.63130
# [453]	validation_0-rmse:3.63122
# [454]	validation_0-rmse:3.63081
# [455]	validation_0-rmse:3.63103
# [456]	validation_0-rmse:3.63066
# [457]	validation_0-rmse:3.63066
# [458]	validation_0-rmse:3.63061
# [459]	validation_0-rmse:3.63063
# [460]	validation_0-rmse:3.63058
# [461]	validation_0-rmse:3.63051
# [462]	validation_0-rmse:3.63046
# [463]	validation_0-rmse:3.63032
# [464]	validation_0-rmse:3.63006
# [465]	validation_0-rmse:3.63002
# [466]	validation_0-rmse:3.62991
# [467]	validation_0-rmse:3.63018
# [468]	validation_0-rmse:3.63006
# [469]	validation_0-rmse:3.63004
# [470]	validation_0-rmse:3.62974
# [471]	validation_0-rmse:3.62923
# [472]	validation_0-rmse:3.62929
# [473]	validation_0-rmse:3.62935
# [474]	validation_0-rmse:3.62923
# [475]	validation_0-rmse:3.62919
# [476]	validation_0-rmse:3.62920
# [477]	validation_0-rmse:3.62916
# [478]	validation_0-rmse:3.62901
# [479]	validation_0-rmse:3.62904
# [480]	validation_0-rmse:3.62900
# [481]	validation_0-rmse:3.62890
# [482]	validation_0-rmse:3.62887
# [483]	validation_0-rmse:3.62897
# [484]	validation_0-rmse:3.62845
# [485]	validation_0-rmse:3.62833
# [486]	validation_0-rmse:3.62804
# [487]	validation_0-rmse:3.62822
# [488]	validation_0-rmse:3.62828
# [489]	validation_0-rmse:3.62814
# [490]	validation_0-rmse:3.62750
# [491]	validation_0-rmse:3.62745
# [492]	validation_0-rmse:3.62751
# [493]	validation_0-rmse:3.62758
# [494]	validation_0-rmse:3.62741
# [495]	validation_0-rmse:3.62730
# [496]	validation_0-rmse:3.62688
# [497]	validation_0-rmse:3.62683
# [498]	validation_0-rmse:3.62681
# [499]	validation_0-rmse:3.62673
# [500]	validation_0-rmse:3.62660
# [501]	validation_0-rmse:3.62646
# [502]	validation_0-rmse:3.62651
# [503]	validation_0-rmse:3.62626
# [504]	validation_0-rmse:3.62624
# [505]	validation_0-rmse:3.62627
# [506]	validation_0-rmse:3.62626
# [507]	validation_0-rmse:3.62628
# [508]	validation_0-rmse:3.62616
# [509]	validation_0-rmse:3.62610
# [510]	validation_0-rmse:3.62606
# [511]	validation_0-rmse:3.62606
# [512]	validation_0-rmse:3.62614
# [513]	validation_0-rmse:3.62627
# [514]	validation_0-rmse:3.62631
# [515]	validation_0-rmse:3.62626
# [516]	validation_0-rmse:3.62613
# [517]	validation_0-rmse:3.62628
# [518]	validation_0-rmse:3.62616
# [519]	validation_0-rmse:3.62603
# [520]	validation_0-rmse:3.62602
# [521]	validation_0-rmse:3.62596
# [522]	validation_0-rmse:3.62595
# [523]	validation_0-rmse:3.62608
# [524]	validation_0-rmse:3.62616
# [525]	validation_0-rmse:3.62618
# [526]	validation_0-rmse:3.62628
# [527]	validation_0-rmse:3.62636
# [528]	validation_0-rmse:3.62618
# [529]	validation_0-rmse:3.62624
# [530]	validation_0-rmse:3.62657
# [531]	validation_0-rmse:3.62645
# [532]	validation_0-rmse:3.62617
# [533]	validation_0-rmse:3.62592
# [534]	validation_0-rmse:3.62583
# [535]	validation_0-rmse:3.62573
# [536]	validation_0-rmse:3.62572
# [537]	validation_0-rmse:3.62570
# [538]	validation_0-rmse:3.62555
# [539]	validation_0-rmse:3.62559
# [540]	validation_0-rmse:3.62542
# [541]	validation_0-rmse:3.62546
# [542]	validation_0-rmse:3.62541
# [543]	validation_0-rmse:3.62545
# [544]	validation_0-rmse:3.62565
# [545]	validation_0-rmse:3.62566
# [546]	validation_0-rmse:3.62568
# [547]	validation_0-rmse:3.62556
# [548]	validation_0-rmse:3.62562
# [549]	validation_0-rmse:3.62554
# [550]	validation_0-rmse:3.62570
# [551]	validation_0-rmse:3.62570
# [552]	validation_0-rmse:3.62558
# [553]	validation_0-rmse:3.62570
# [554]	validation_0-rmse:3.62533
# [555]	validation_0-rmse:3.62527
# [556]	validation_0-rmse:3.62523
# [557]	validation_0-rmse:3.62535
# [558]	validation_0-rmse:3.62530
# [559]	validation_0-rmse:3.62529
# [560]	validation_0-rmse:3.62521
# [561]	validation_0-rmse:3.62511
# [562]	validation_0-rmse:3.62510
# [563]	validation_0-rmse:3.62508
# [564]	validation_0-rmse:3.62511
# [565]	validation_0-rmse:3.62493
# [566]	validation_0-rmse:3.62478
# [567]	validation_0-rmse:3.62517
# [568]	validation_0-rmse:3.62524
# [569]	validation_0-rmse:3.62523
# [570]	validation_0-rmse:3.62507
# [571]	validation_0-rmse:3.62507
# [572]	validation_0-rmse:3.62514
# [573]	validation_0-rmse:3.62507
# [574]	validation_0-rmse:3.62467
# [575]	validation_0-rmse:3.62470
# [576]	validation_0-rmse:3.62478
# [577]	validation_0-rmse:3.62483
# [578]	validation_0-rmse:3.62468
# [579]	validation_0-rmse:3.62472
# [580]	validation_0-rmse:3.62471
# [581]	validation_0-rmse:3.62442
# [582]	validation_0-rmse:3.62444
# [583]	validation_0-rmse:3.62427
# [584]	validation_0-rmse:3.62417
# [585]	validation_0-rmse:3.62441
# [586]	validation_0-rmse:3.62433
# [587]	validation_0-rmse:3.62428
# [588]	validation_0-rmse:3.62440
# [589]	validation_0-rmse:3.62420
# [590]	validation_0-rmse:3.62390
# [591]	validation_0-rmse:3.62386
# [592]	validation_0-rmse:3.62384
# [593]	validation_0-rmse:3.62387
# [594]	validation_0-rmse:3.62382
# [595]	validation_0-rmse:3.62393
# [596]	validation_0-rmse:3.62382
# [597]	validation_0-rmse:3.62372
# [598]	validation_0-rmse:3.62380
# [599]	validation_0-rmse:3.62377
# [600]	validation_0-rmse:3.62380
# [601]	validation_0-rmse:3.62391
# [602]	validation_0-rmse:3.62427
# [603]	validation_0-rmse:3.62431
# [604]	validation_0-rmse:3.62410
# [605]	validation_0-rmse:3.62414
# [606]	validation_0-rmse:3.62409
# [607]	validation_0-rmse:3.62410
# [608]	validation_0-rmse:3.62398
# [609]	validation_0-rmse:3.62396
# [610]	validation_0-rmse:3.62421
# [611]	validation_0-rmse:3.62439
# [612]	validation_0-rmse:3.62429
# [613]	validation_0-rmse:3.62421
# [614]	validation_0-rmse:3.62406
# [615]	validation_0-rmse:3.62396
# [616]	validation_0-rmse:3.62396
# [617]	validation_0-rmse:3.62385
# [618]	validation_0-rmse:3.62377
# [619]	validation_0-rmse:3.62378
# [620]	validation_0-rmse:3.62375
# [621]	validation_0-rmse:3.62384
# [622]	validation_0-rmse:3.62377
# [623]	validation_0-rmse:3.62368
# [624]	validation_0-rmse:3.62373
# [625]	validation_0-rmse:3.62368
# [626]	validation_0-rmse:3.62359
# [627]	validation_0-rmse:3.62350
# [628]	validation_0-rmse:3.62351
# [629]	validation_0-rmse:3.62346
# [630]	validation_0-rmse:3.62401
# [631]	validation_0-rmse:3.62412
# [632]	validation_0-rmse:3.62408
# [633]	validation_0-rmse:3.62406
# [634]	validation_0-rmse:3.62402
# [635]	validation_0-rmse:3.62414
# [636]	validation_0-rmse:3.62414
# [637]	validation_0-rmse:3.62401
# [638]	validation_0-rmse:3.62402
# [639]	validation_0-rmse:3.62391
# [640]	validation_0-rmse:3.62384
# [641]	validation_0-rmse:3.62369
# [642]	validation_0-rmse:3.62373
# [643]	validation_0-rmse:3.62385
# [644]	validation_0-rmse:3.62401
# [645]	validation_0-rmse:3.62403
# [646]	validation_0-rmse:3.62409
# [647]	validation_0-rmse:3.62396
# [648]	validation_0-rmse:3.62396
# [649]	validation_0-rmse:3.62388
# [650]	validation_0-rmse:3.62387
# [651]	validation_0-rmse:3.62357
# [652]	validation_0-rmse:3.62359
# [653]	validation_0-rmse:3.62353
# [654]	validation_0-rmse:3.62354
# [655]	validation_0-rmse:3.62333
# [656]	validation_0-rmse:3.62332
# [657]	validation_0-rmse:3.62334
# [658]	validation_0-rmse:3.62331
# [659]	validation_0-rmse:3.62341
# [660]	validation_0-rmse:3.62346
# [661]	validation_0-rmse:3.62340
# [662]	validation_0-rmse:3.62317
# [663]	validation_0-rmse:3.62309
# [664]	validation_0-rmse:3.62319
# [665]	validation_0-rmse:3.62311
# [666]	validation_0-rmse:3.62311
# [667]	validation_0-rmse:3.62301
# [668]	validation_0-rmse:3.62309
# [669]	validation_0-rmse:3.62298
# [670]	validation_0-rmse:3.62304
# [671]	validation_0-rmse:3.62303
# [672]	validation_0-rmse:3.62292
# [673]	validation_0-rmse:3.62302
# [674]	validation_0-rmse:3.62299
# [675]	validation_0-rmse:3.62314
# [676]	validation_0-rmse:3.62321
# [677]	validation_0-rmse:3.62296
# [678]	validation_0-rmse:3.62293
# [679]	validation_0-rmse:3.62285
# [680]	validation_0-rmse:3.62272
# [681]	validation_0-rmse:3.62270
# [682]	validation_0-rmse:3.62251
# [683]	validation_0-rmse:3.62251
# [684]	validation_0-rmse:3.62250
# [685]	validation_0-rmse:3.62253
# [686]	validation_0-rmse:3.62243
# [687]	validation_0-rmse:3.62245
# [688]	validation_0-rmse:3.62255
# [689]	validation_0-rmse:3.62253
# [690]	validation_0-rmse:3.62253
# [691]	validation_0-rmse:3.62256
# [692]	validation_0-rmse:3.62259
# [693]	validation_0-rmse:3.62249
# [694]	validation_0-rmse:3.62251
# [695]	validation_0-rmse:3.62258
# [696]	validation_0-rmse:3.62253
# [697]	validation_0-rmse:3.62270
# [698]	validation_0-rmse:3.62297
# [699]	validation_0-rmse:3.62296
# [700]	validation_0-rmse:3.62288
# [701]	validation_0-rmse:3.62265
# [702]	validation_0-rmse:3.62267
# [703]	validation_0-rmse:3.62267
# [704]	validation_0-rmse:3.62252
# [705]	validation_0-rmse:3.62297
# [706]	validation_0-rmse:3.62310
# [707]	validation_0-rmse:3.62318
# [708]	validation_0-rmse:3.62333
# [709]	validation_0-rmse:3.62334
# [710]	validation_0-rmse:3.62337
# [711]	validation_0-rmse:3.62338
# [712]	validation_0-rmse:3.62335
# [713]	validation_0-rmse:3.62335
# [714]	validation_0-rmse:3.62337
# [715]	validation_0-rmse:3.62331
# [716]	validation_0-rmse:3.62333
# [717]	validation_0-rmse:3.62314
# [718]	validation_0-rmse:3.62323
# [719]	validation_0-rmse:3.62332
# [720]	validation_0-rmse:3.62343
# [721]	validation_0-rmse:3.62339
# [722]	validation_0-rmse:3.62327
# [723]	validation_0-rmse:3.62328
# [724]	validation_0-rmse:3.62325
# [725]	validation_0-rmse:3.62346
# [726]	validation_0-rmse:3.62338
# [727]	validation_0-rmse:3.62350
# [728]	validation_0-rmse:3.62350
# [729]	validation_0-rmse:3.62356
# [730]	validation_0-rmse:3.62385
# [731]	validation_0-rmse:3.62383
# [732]	validation_0-rmse:3.62379
# [733]	validation_0-rmse:3.62380
# [734]	validation_0-rmse:3.62379
# [735]	validation_0-rmse:3.62384
# [0]	validation_0-rmse:59.37381
# [1]	validation_0-rmse:56.45113
# [2]	validation_0-rmse:53.67436
# [3]	validation_0-rmse:51.05314
# [4]	validation_0-rmse:48.54784
# [5]	validation_0-rmse:46.16853
# [6]	validation_0-rmse:43.92205
# [7]	validation_0-rmse:41.77321
# [8]	validation_0-rmse:39.73157
# [9]	validation_0-rmse:37.80949
# [10]	validation_0-rmse:35.96917
# [11]	validation_0-rmse:34.23319
# [12]	validation_0-rmse:32.57287
# [13]	validation_0-rmse:30.99558
# [14]	validation_0-rmse:29.49675
# [15]	validation_0-rmse:28.07773
# [16]	validation_0-rmse:26.72698
# [17]	validation_0-rmse:25.45870
# [18]	validation_0-rmse:24.24468
# [19]	validation_0-rmse:23.08905
# [20]	validation_0-rmse:21.99173
# [21]	validation_0-rmse:20.95176
# [22]	validation_0-rmse:19.96492
# [23]	validation_0-rmse:19.03183
# [24]	validation_0-rmse:18.14957
# [25]	validation_0-rmse:17.31758
# [26]	validation_0-rmse:16.51850
# [27]	validation_0-rmse:15.77310
# [28]	validation_0-rmse:15.05554
# [29]	validation_0-rmse:14.37822
# [30]	validation_0-rmse:13.73688
# [31]	validation_0-rmse:13.12927
# [32]	validation_0-rmse:12.55882
# [33]	validation_0-rmse:12.01182
# [34]	validation_0-rmse:11.50357
# [35]	validation_0-rmse:11.01583
# [36]	validation_0-rmse:10.55581
# [37]	validation_0-rmse:10.12424
# [38]	validation_0-rmse:9.71150
# [39]	validation_0-rmse:9.32317
# [40]	validation_0-rmse:8.96162
# [41]	validation_0-rmse:8.61581
# [42]	validation_0-rmse:8.29337
# [43]	validation_0-rmse:7.99175
# [44]	validation_0-rmse:7.70592
# [45]	validation_0-rmse:7.43656
# [46]	validation_0-rmse:7.18214
# [47]	validation_0-rmse:6.94391
# [48]	validation_0-rmse:6.71971
# [49]	validation_0-rmse:6.51336
# [50]	validation_0-rmse:6.31536
# [51]	validation_0-rmse:6.13226
# [52]	validation_0-rmse:5.96008
# [53]	validation_0-rmse:5.80166
# [54]	validation_0-rmse:5.65441
# [55]	validation_0-rmse:5.51615
# [56]	validation_0-rmse:5.38372
# [57]	validation_0-rmse:5.26435
# [58]	validation_0-rmse:5.15179
# [59]	validation_0-rmse:5.04752
# [60]	validation_0-rmse:4.95088
# [61]	validation_0-rmse:4.85962
# [62]	validation_0-rmse:4.77625
# [63]	validation_0-rmse:4.69996
# [64]	validation_0-rmse:4.63020
# [65]	validation_0-rmse:4.56478
# [66]	validation_0-rmse:4.50293
# [67]	validation_0-rmse:4.44853
# [68]	validation_0-rmse:4.39620
# [69]	validation_0-rmse:4.34602
# [70]	validation_0-rmse:4.29953
# [71]	validation_0-rmse:4.25589
# [72]	validation_0-rmse:4.21738
# [73]	validation_0-rmse:4.18112
# [74]	validation_0-rmse:4.14854
# [75]	validation_0-rmse:4.11947
# [76]	validation_0-rmse:4.09186
# [77]	validation_0-rmse:4.06380
# [78]	validation_0-rmse:4.04067
# [79]	validation_0-rmse:4.01885
# [80]	validation_0-rmse:3.99861
# [81]	validation_0-rmse:3.98057
# [82]	validation_0-rmse:3.96359
# [83]	validation_0-rmse:3.94652
# [84]	validation_0-rmse:3.93169
# [85]	validation_0-rmse:3.91695
# [86]	validation_0-rmse:3.90311
# [87]	validation_0-rmse:3.89063
# [88]	validation_0-rmse:3.87776
# [89]	validation_0-rmse:3.86776
# [90]	validation_0-rmse:3.85831
# [91]	validation_0-rmse:3.85031
# [92]	validation_0-rmse:3.84099
# [93]	validation_0-rmse:3.83223
# [94]	validation_0-rmse:3.82520
# [95]	validation_0-rmse:3.81881
# [96]	validation_0-rmse:3.81250
# [97]	validation_0-rmse:3.80626
# [98]	validation_0-rmse:3.79937
# [99]	validation_0-rmse:3.79497
# [100]	validation_0-rmse:3.79125
# [101]	validation_0-rmse:3.78547
# [102]	validation_0-rmse:3.77959
# [103]	validation_0-rmse:3.77588
# [104]	validation_0-rmse:3.77117
# [105]	validation_0-rmse:3.76869
# [106]	validation_0-rmse:3.76390
# [107]	validation_0-rmse:3.75961
# [108]	validation_0-rmse:3.75651
# [109]	validation_0-rmse:3.75117
# [110]	validation_0-rmse:3.74728
# [111]	validation_0-rmse:3.74539
# [112]	validation_0-rmse:3.74385
# [113]	validation_0-rmse:3.73909
# [114]	validation_0-rmse:3.73493
# [115]	validation_0-rmse:3.73279
# [116]	validation_0-rmse:3.73189
# [117]	validation_0-rmse:3.73061
# [118]	validation_0-rmse:3.72723
# [119]	validation_0-rmse:3.72471
# [120]	validation_0-rmse:3.72322
# [121]	validation_0-rmse:3.72091
# [122]	validation_0-rmse:3.71991
# [123]	validation_0-rmse:3.71824
# [124]	validation_0-rmse:3.71729
# [125]	validation_0-rmse:3.71619
# [126]	validation_0-rmse:3.71470
# [127]	validation_0-rmse:3.71193
# [128]	validation_0-rmse:3.70972
# [129]	validation_0-rmse:3.70840
# [130]	validation_0-rmse:3.70746
# [131]	validation_0-rmse:3.70618
# [132]	validation_0-rmse:3.70309
# [133]	validation_0-rmse:3.70223
# [134]	validation_0-rmse:3.70004
# [135]	validation_0-rmse:3.69885
# [136]	validation_0-rmse:3.69753
# [137]	validation_0-rmse:3.69665
# [138]	validation_0-rmse:3.69586
# [139]	validation_0-rmse:3.69562
# [140]	validation_0-rmse:3.69505
# [141]	validation_0-rmse:3.69324
# [142]	validation_0-rmse:3.69172
# [143]	validation_0-rmse:3.69085
# [144]	validation_0-rmse:3.68880
# [145]	validation_0-rmse:3.68726
# [146]	validation_0-rmse:3.68661
# [147]	validation_0-rmse:3.68575
# [148]	validation_0-rmse:3.68524
# [149]	validation_0-rmse:3.68491
# [150]	validation_0-rmse:3.68394
# [151]	validation_0-rmse:3.68347
# [152]	validation_0-rmse:3.68053
# [153]	validation_0-rmse:3.67990
# [154]	validation_0-rmse:3.67897
# [155]	validation_0-rmse:3.67817
# [156]	validation_0-rmse:3.67773
# [157]	validation_0-rmse:3.67537
# [158]	validation_0-rmse:3.67511
# [159]	validation_0-rmse:3.67453
# [160]	validation_0-rmse:3.67420
# [161]	validation_0-rmse:3.67297
# [162]	validation_0-rmse:3.67178
# [163]	validation_0-rmse:3.67142
# [164]	validation_0-rmse:3.67063
# [165]	validation_0-rmse:3.66977
# [166]	validation_0-rmse:3.66964
# [167]	validation_0-rmse:3.66931
# [168]	validation_0-rmse:3.66927
# [169]	validation_0-rmse:3.66899
# [170]	validation_0-rmse:3.66891
# [171]	validation_0-rmse:3.66888
# [172]	validation_0-rmse:3.66857
# [173]	validation_0-rmse:3.66872
# [174]	validation_0-rmse:3.66868
# [175]	validation_0-rmse:3.66795
# [176]	validation_0-rmse:3.66740
# [177]	validation_0-rmse:3.66685
# [178]	validation_0-rmse:3.66656
# [179]	validation_0-rmse:3.66602
# [180]	validation_0-rmse:3.66607
# [181]	validation_0-rmse:3.66579
# [182]	validation_0-rmse:3.66575
# [183]	validation_0-rmse:3.66502
# [184]	validation_0-rmse:3.66440
# [185]	validation_0-rmse:3.66376
# [186]	validation_0-rmse:3.66352
# [187]	validation_0-rmse:3.66313
# [188]	validation_0-rmse:3.66290
# [189]	validation_0-rmse:3.66289
# [190]	validation_0-rmse:3.66268
# [191]	validation_0-rmse:3.66291
# [192]	validation_0-rmse:3.66272
# [193]	validation_0-rmse:3.66259
# [194]	validation_0-rmse:3.66241
# [195]	validation_0-rmse:3.66243
# [196]	validation_0-rmse:3.66182
# [197]	validation_0-rmse:3.66195
# [198]	validation_0-rmse:3.66144
# [199]	validation_0-rmse:3.66122
# [200]	validation_0-rmse:3.66110
# [201]	validation_0-rmse:3.66092
# [202]	validation_0-rmse:3.66113
# [203]	validation_0-rmse:3.66066
# [204]	validation_0-rmse:3.66049
# [205]	validation_0-rmse:3.66025
# [206]	validation_0-rmse:3.66003
# [207]	validation_0-rmse:3.66008
# [208]	validation_0-rmse:3.65948
# [209]	validation_0-rmse:3.65930
# [210]	validation_0-rmse:3.65944
# [211]	validation_0-rmse:3.65951
# [212]	validation_0-rmse:3.65914
# [213]	validation_0-rmse:3.65893
# [214]	validation_0-rmse:3.65918
# [215]	validation_0-rmse:3.65929
# [216]	validation_0-rmse:3.65891
# [217]	validation_0-rmse:3.65835
# [218]	validation_0-rmse:3.65808
# [219]	validation_0-rmse:3.65793
# [220]	validation_0-rmse:3.65795
# [221]	validation_0-rmse:3.65745
# [222]	validation_0-rmse:3.65609
# [223]	validation_0-rmse:3.65608
# [224]	validation_0-rmse:3.65644
# [225]	validation_0-rmse:3.65613
# [226]	validation_0-rmse:3.65610
# [227]	validation_0-rmse:3.65598
# [228]	validation_0-rmse:3.65591
# [229]	validation_0-rmse:3.65558
# [230]	validation_0-rmse:3.65525
# [231]	validation_0-rmse:3.65550
# [232]	validation_0-rmse:3.65525
# [233]	validation_0-rmse:3.65518
# [234]	validation_0-rmse:3.65455
# [235]	validation_0-rmse:3.65432
# [236]	validation_0-rmse:3.65434
# [237]	validation_0-rmse:3.65387
# [238]	validation_0-rmse:3.65422
# [239]	validation_0-rmse:3.65440
# [240]	validation_0-rmse:3.65405
# [241]	validation_0-rmse:3.65395
# [242]	validation_0-rmse:3.65381
# [243]	validation_0-rmse:3.65382
# [244]	validation_0-rmse:3.65345
# [245]	validation_0-rmse:3.65342
# [246]	validation_0-rmse:3.65306
# [247]	validation_0-rmse:3.65300
# [248]	validation_0-rmse:3.65292
# [249]	validation_0-rmse:3.65243
# [250]	validation_0-rmse:3.65104
# [251]	validation_0-rmse:3.65081
# [252]	validation_0-rmse:3.65067
# [253]	validation_0-rmse:3.65045
# [254]	validation_0-rmse:3.65000
# [255]	validation_0-rmse:3.64893
# [256]	validation_0-rmse:3.64887
# [257]	validation_0-rmse:3.64876
# [258]	validation_0-rmse:3.64835
# [259]	validation_0-rmse:3.64832
# [260]	validation_0-rmse:3.64826
# [261]	validation_0-rmse:3.64812
# [262]	validation_0-rmse:3.64792
# [263]	validation_0-rmse:3.64769
# [264]	validation_0-rmse:3.64761
# [265]	validation_0-rmse:3.64745
# [266]	validation_0-rmse:3.64711
# [267]	validation_0-rmse:3.64701
# [268]	validation_0-rmse:3.64699
# [269]	validation_0-rmse:3.64706
# [270]	validation_0-rmse:3.64697
# [271]	validation_0-rmse:3.64668
# [272]	validation_0-rmse:3.64706
# [273]	validation_0-rmse:3.64687
# [274]	validation_0-rmse:3.64626
# [275]	validation_0-rmse:3.64660
# [276]	validation_0-rmse:3.64631
# [277]	validation_0-rmse:3.64623
# [278]	validation_0-rmse:3.64581
# [279]	validation_0-rmse:3.64534
# [280]	validation_0-rmse:3.64495
# [281]	validation_0-rmse:3.64459
# [282]	validation_0-rmse:3.64450
# [283]	validation_0-rmse:3.64423
# [284]	validation_0-rmse:3.64409
# [285]	validation_0-rmse:3.64418
# [286]	validation_0-rmse:3.64384
# [287]	validation_0-rmse:3.64397
# [288]	validation_0-rmse:3.64405
# [289]	validation_0-rmse:3.64384
# [290]	validation_0-rmse:3.64365
# [291]	validation_0-rmse:3.64350
# [292]	validation_0-rmse:3.64306
# [293]	validation_0-rmse:3.64297
# [294]	validation_0-rmse:3.64295
# [295]	validation_0-rmse:3.64312
# [296]	validation_0-rmse:3.64287
# [297]	validation_0-rmse:3.64285
# [298]	validation_0-rmse:3.64225
# [299]	validation_0-rmse:3.64198
# [300]	validation_0-rmse:3.64200
# [301]	validation_0-rmse:3.64171
# [302]	validation_0-rmse:3.64144
# [303]	validation_0-rmse:3.64146
# [304]	validation_0-rmse:3.64130
# [305]	validation_0-rmse:3.64171
# [306]	validation_0-rmse:3.64149
# [307]	validation_0-rmse:3.64146
# [308]	validation_0-rmse:3.64137
# [309]	validation_0-rmse:3.64087
# [310]	validation_0-rmse:3.64074
# [311]	validation_0-rmse:3.64084
# [312]	validation_0-rmse:3.64060
# [313]	validation_0-rmse:3.64044
# [314]	validation_0-rmse:3.64037
# [315]	validation_0-rmse:3.64024
# [316]	validation_0-rmse:3.64038
# [317]	validation_0-rmse:3.64028
# [318]	validation_0-rmse:3.64002
# [319]	validation_0-rmse:3.64003
# [320]	validation_0-rmse:3.63992
# [321]	validation_0-rmse:3.63985
# [322]	validation_0-rmse:3.63946
# [323]	validation_0-rmse:3.63951
# [324]	validation_0-rmse:3.63947
# [325]	validation_0-rmse:3.63925
# [326]	validation_0-rmse:3.63852
# [327]	validation_0-rmse:3.63841
# [328]	validation_0-rmse:3.63835
# [329]	validation_0-rmse:3.63821
# [330]	validation_0-rmse:3.63815
# [331]	validation_0-rmse:3.63824
# [332]	validation_0-rmse:3.63807
# [333]	validation_0-rmse:3.63819
# [334]	validation_0-rmse:3.63821
# [335]	validation_0-rmse:3.63772
# [336]	validation_0-rmse:3.63769
# [337]	validation_0-rmse:3.63754
# [338]	validation_0-rmse:3.63737
# [339]	validation_0-rmse:3.63763
# [340]	validation_0-rmse:3.63753
# [341]	validation_0-rmse:3.63740
# [342]	validation_0-rmse:3.63726
# [343]	validation_0-rmse:3.63712
# [344]	validation_0-rmse:3.63703
# [345]	validation_0-rmse:3.63705
# [346]	validation_0-rmse:3.63718
# [347]	validation_0-rmse:3.63702
# [348]	validation_0-rmse:3.63692
# [349]	validation_0-rmse:3.63690
# [350]	validation_0-rmse:3.63668
# [351]	validation_0-rmse:3.63663
# [352]	validation_0-rmse:3.63648
# [353]	validation_0-rmse:3.63647
# [354]	validation_0-rmse:3.63625
# [355]	validation_0-rmse:3.63586
# [356]	validation_0-rmse:3.63578
# [357]	validation_0-rmse:3.63581
# [358]	validation_0-rmse:3.63563
# [359]	validation_0-rmse:3.63557
# [360]	validation_0-rmse:3.63547
# [361]	validation_0-rmse:3.63549
# [362]	validation_0-rmse:3.63513
# [363]	validation_0-rmse:3.63512
# [364]	validation_0-rmse:3.63509
# [365]	validation_0-rmse:3.63486
# [366]	validation_0-rmse:3.63478
# [367]	validation_0-rmse:3.63463
# [368]	validation_0-rmse:3.63429
# [369]	validation_0-rmse:3.63431
# [370]	validation_0-rmse:3.63412
# [371]	validation_0-rmse:3.63414
# [372]	validation_0-rmse:3.63410
# [373]	validation_0-rmse:3.63438
# [374]	validation_0-rmse:3.63419
# [375]	validation_0-rmse:3.63370
# [376]	validation_0-rmse:3.63349
# [377]	validation_0-rmse:3.63332
# [378]	validation_0-rmse:3.63267
# [379]	validation_0-rmse:3.63265
# [380]	validation_0-rmse:3.63256
# [381]	validation_0-rmse:3.63259
# [382]	validation_0-rmse:3.63263
# [383]	validation_0-rmse:3.63257
# [384]	validation_0-rmse:3.63217
# [385]	validation_0-rmse:3.63212
# [386]	validation_0-rmse:3.63187
# [387]	validation_0-rmse:3.63200
# [388]	validation_0-rmse:3.63176
# [389]	validation_0-rmse:3.63174
# [390]	validation_0-rmse:3.63157
# [391]	validation_0-rmse:3.63151
# [392]	validation_0-rmse:3.63144
# [393]	validation_0-rmse:3.63155
# [394]	validation_0-rmse:3.63145
# [395]	validation_0-rmse:3.63143
# [396]	validation_0-rmse:3.63137
# [397]	validation_0-rmse:3.63146
# [398]	validation_0-rmse:3.63135
# [399]	validation_0-rmse:3.63135
# [400]	validation_0-rmse:3.63131
# [401]	validation_0-rmse:3.63117
# [402]	validation_0-rmse:3.63115
# [403]	validation_0-rmse:3.63104
# [404]	validation_0-rmse:3.63095
# [405]	validation_0-rmse:3.63081
# [406]	validation_0-rmse:3.63016
# [407]	validation_0-rmse:3.63022
# [408]	validation_0-rmse:3.62990
# [409]	validation_0-rmse:3.62984
# [410]	validation_0-rmse:3.62972
# [411]	validation_0-rmse:3.62948
# [412]	validation_0-rmse:3.62953
# [413]	validation_0-rmse:3.62968
# [414]	validation_0-rmse:3.62871
# [415]	validation_0-rmse:3.62886
# [416]	validation_0-rmse:3.62879
# [417]	validation_0-rmse:3.62847
# [418]	validation_0-rmse:3.62845
# [419]	validation_0-rmse:3.62828
# [420]	validation_0-rmse:3.62837
# [421]	validation_0-rmse:3.62848
# [422]	validation_0-rmse:3.62840
# [423]	validation_0-rmse:3.62834
# [424]	validation_0-rmse:3.62797
# [425]	validation_0-rmse:3.62768
# [426]	validation_0-rmse:3.62742
# [427]	validation_0-rmse:3.62734
# [428]	validation_0-rmse:3.62728
# [429]	validation_0-rmse:3.62728
# [430]	validation_0-rmse:3.62719
# [431]	validation_0-rmse:3.62716
# [432]	validation_0-rmse:3.62731
# [433]	validation_0-rmse:3.62732
# [434]	validation_0-rmse:3.62728
# [435]	validation_0-rmse:3.62714
# [436]	validation_0-rmse:3.62720
# [437]	validation_0-rmse:3.62737
# [438]	validation_0-rmse:3.62734
# [439]	validation_0-rmse:3.62736
# [440]	validation_0-rmse:3.62734
# [441]	validation_0-rmse:3.62728
# [442]	validation_0-rmse:3.62701
# [443]	validation_0-rmse:3.62619
# [444]	validation_0-rmse:3.62610
# [445]	validation_0-rmse:3.62602
# [446]	validation_0-rmse:3.62589
# [447]	validation_0-rmse:3.62569
# [448]	validation_0-rmse:3.62543
# [449]	validation_0-rmse:3.62496
# [450]	validation_0-rmse:3.62495
# [451]	validation_0-rmse:3.62487
# [452]	validation_0-rmse:3.62450
# [453]	validation_0-rmse:3.62439
# [454]	validation_0-rmse:3.62449
# [455]	validation_0-rmse:3.62447
# [456]	validation_0-rmse:3.62425
# [457]	validation_0-rmse:3.62427
# [458]	validation_0-rmse:3.62444
# [459]	validation_0-rmse:3.62438
# [460]	validation_0-rmse:3.62416
# [461]	validation_0-rmse:3.62374
# [462]	validation_0-rmse:3.62368
# [463]	validation_0-rmse:3.62365
# [464]	validation_0-rmse:3.62347
# [465]	validation_0-rmse:3.62336
# [466]	validation_0-rmse:3.62327
# [467]	validation_0-rmse:3.62309
# [468]	validation_0-rmse:3.62292
# [469]	validation_0-rmse:3.62290
# [470]	validation_0-rmse:3.62282
# [471]	validation_0-rmse:3.62283
# [472]	validation_0-rmse:3.62285
# [473]	validation_0-rmse:3.62286
# [474]	validation_0-rmse:3.62264
# [475]	validation_0-rmse:3.62254
# [476]	validation_0-rmse:3.62238
# [477]	validation_0-rmse:3.62234
# [478]	validation_0-rmse:3.62239
# [479]	validation_0-rmse:3.62234
# [480]	validation_0-rmse:3.62229
# [481]	validation_0-rmse:3.62241
# [482]	validation_0-rmse:3.62244
# [483]	validation_0-rmse:3.62226
# [484]	validation_0-rmse:3.62232
# [485]	validation_0-rmse:3.62233
# [486]	validation_0-rmse:3.62206
# [487]	validation_0-rmse:3.62195
# [488]	validation_0-rmse:3.62189
# [489]	validation_0-rmse:3.62187
# [490]	validation_0-rmse:3.62160
# [491]	validation_0-rmse:3.62131
# [492]	validation_0-rmse:3.62132
# [493]	validation_0-rmse:3.62128
# [494]	validation_0-rmse:3.62121
# [495]	validation_0-rmse:3.62122
# [496]	validation_0-rmse:3.62120
# [497]	validation_0-rmse:3.62119
# [498]	validation_0-rmse:3.62113
# [499]	validation_0-rmse:3.62096
# [500]	validation_0-rmse:3.62088
# [501]	validation_0-rmse:3.62089
# [502]	validation_0-rmse:3.62092
# [503]	validation_0-rmse:3.62088
# [504]	validation_0-rmse:3.62088
# [505]	validation_0-rmse:3.62095
# [506]	validation_0-rmse:3.62096
# [507]	validation_0-rmse:3.62090
# [508]	validation_0-rmse:3.62091
# [509]	validation_0-rmse:3.62093
# [510]	validation_0-rmse:3.62108
# [511]	validation_0-rmse:3.62105
# [512]	validation_0-rmse:3.62072
# [513]	validation_0-rmse:3.62075
# [514]	validation_0-rmse:3.62056
# [515]	validation_0-rmse:3.62057
# [516]	validation_0-rmse:3.62052
# [517]	validation_0-rmse:3.62055
# [518]	validation_0-rmse:3.62050
# [519]	validation_0-rmse:3.62049
# [520]	validation_0-rmse:3.62052
# [521]	validation_0-rmse:3.62046
# [522]	validation_0-rmse:3.62058
# [523]	validation_0-rmse:3.62055
# [524]	validation_0-rmse:3.62068
# [525]	validation_0-rmse:3.62087
# [526]	validation_0-rmse:3.62111
# [527]	validation_0-rmse:3.62112
# [528]	validation_0-rmse:3.62118
# [529]	validation_0-rmse:3.62115
# [530]	validation_0-rmse:3.62136
# [531]	validation_0-rmse:3.62138
# [532]	validation_0-rmse:3.62126
# [533]	validation_0-rmse:3.62123
# [534]	validation_0-rmse:3.62108
# [535]	validation_0-rmse:3.62086
# [536]	validation_0-rmse:3.62087
# [537]	validation_0-rmse:3.62067
# [538]	validation_0-rmse:3.62052
# [539]	validation_0-rmse:3.62052
# [540]	validation_0-rmse:3.62045
# [541]	validation_0-rmse:3.62036
# [542]	validation_0-rmse:3.62037
# [543]	validation_0-rmse:3.62033
# [544]	validation_0-rmse:3.62041
# [545]	validation_0-rmse:3.62047
# [546]	validation_0-rmse:3.62059
# [547]	validation_0-rmse:3.62040
# [548]	validation_0-rmse:3.62036
# [549]	validation_0-rmse:3.62029
# [550]	validation_0-rmse:3.61967
# [551]	validation_0-rmse:3.61950
# [552]	validation_0-rmse:3.61942
# [553]	validation_0-rmse:3.61927
# [554]	validation_0-rmse:3.61939
# [555]	validation_0-rmse:3.61932
# [556]	validation_0-rmse:3.61915
# [557]	validation_0-rmse:3.61917
# [558]	validation_0-rmse:3.61912
# [559]	validation_0-rmse:3.61909
# [560]	validation_0-rmse:3.61915
# [561]	validation_0-rmse:3.61906
# [562]	validation_0-rmse:3.61904
# [563]	validation_0-rmse:3.61894
# [564]	validation_0-rmse:3.61887
# [565]	validation_0-rmse:3.61881
# [566]	validation_0-rmse:3.61939
# [567]	validation_0-rmse:3.61911
# [568]	validation_0-rmse:3.61902
# [569]	validation_0-rmse:3.61905
# [570]	validation_0-rmse:3.61894
# [571]	validation_0-rmse:3.61912
# [572]	validation_0-rmse:3.61938
# [573]	validation_0-rmse:3.61931
# [574]	validation_0-rmse:3.61935
# [575]	validation_0-rmse:3.61920
# [576]	validation_0-rmse:3.61896
# [577]	validation_0-rmse:3.61883
# [578]	validation_0-rmse:3.61889
# [579]	validation_0-rmse:3.61893
# [580]	validation_0-rmse:3.61893
# [581]	validation_0-rmse:3.61897
# [582]	validation_0-rmse:3.61888
# [583]	validation_0-rmse:3.61873
# [584]	validation_0-rmse:3.61852
# [585]	validation_0-rmse:3.61854
# [586]	validation_0-rmse:3.61844
# [587]	validation_0-rmse:3.61758
# [588]	validation_0-rmse:3.61746
# [589]	validation_0-rmse:3.61743
# [590]	validation_0-rmse:3.61736
# [591]	validation_0-rmse:3.61744
# [592]	validation_0-rmse:3.61739
# [593]	validation_0-rmse:3.61733
# [594]	validation_0-rmse:3.61714
# [595]	validation_0-rmse:3.61707
# [596]	validation_0-rmse:3.61694
# [597]	validation_0-rmse:3.61688
# [598]	validation_0-rmse:3.61684
# [599]	validation_0-rmse:3.61686
# [600]	validation_0-rmse:3.61673
# [601]	validation_0-rmse:3.61677
# [602]	validation_0-rmse:3.61648
# [603]	validation_0-rmse:3.61655
# [604]	validation_0-rmse:3.61664
# [605]	validation_0-rmse:3.61659
# [606]	validation_0-rmse:3.61654
# [607]	validation_0-rmse:3.61621
# [608]	validation_0-rmse:3.61611
# [609]	validation_0-rmse:3.61608
# [610]	validation_0-rmse:3.61615
# [611]	validation_0-rmse:3.61599
# [612]	validation_0-rmse:3.61598
# [613]	validation_0-rmse:3.61602
# [614]	validation_0-rmse:3.61590
# [615]	validation_0-rmse:3.61573
# [616]	validation_0-rmse:3.61563
# [617]	validation_0-rmse:3.61552
# [618]	validation_0-rmse:3.61539
# [619]	validation_0-rmse:3.61527
# [620]	validation_0-rmse:3.61523
# [621]	validation_0-rmse:3.61537
# [622]	validation_0-rmse:3.61532
# [623]	validation_0-rmse:3.61525
# [624]	validation_0-rmse:3.61525
# [625]	validation_0-rmse:3.61525
# [626]	validation_0-rmse:3.61534
# [627]	validation_0-rmse:3.61520
# [628]	validation_0-rmse:3.61511
# [629]	validation_0-rmse:3.61502
# [630]	validation_0-rmse:3.61496
# [631]	validation_0-rmse:3.61480
# [632]	validation_0-rmse:3.61429
# [633]	validation_0-rmse:3.61431
# [634]	validation_0-rmse:3.61430
# [635]	validation_0-rmse:3.61433
# [636]	validation_0-rmse:3.61430
# [637]	validation_0-rmse:3.61420
# [638]	validation_0-rmse:3.61431
# [639]	validation_0-rmse:3.61445
# [640]	validation_0-rmse:3.61442
# [641]	validation_0-rmse:3.61441
# [642]	validation_0-rmse:3.61441
# [643]	validation_0-rmse:3.61449
# [644]	validation_0-rmse:3.61432
# [645]	validation_0-rmse:3.61418
# [646]	validation_0-rmse:3.61398
# [647]	validation_0-rmse:3.61393
# [648]	validation_0-rmse:3.61386
# [649]	validation_0-rmse:3.61393
# [650]	validation_0-rmse:3.61400
# [651]	validation_0-rmse:3.61399
# [652]	validation_0-rmse:3.61395
# [653]	validation_0-rmse:3.61391
# [654]	validation_0-rmse:3.61390
# [655]	validation_0-rmse:3.61370
# [656]	validation_0-rmse:3.61359
# [657]	validation_0-rmse:3.61357
# [658]	validation_0-rmse:3.61381
# [659]	validation_0-rmse:3.61387
# [660]	validation_0-rmse:3.61388
# [661]	validation_0-rmse:3.61400
# [662]	validation_0-rmse:3.61397
# [663]	validation_0-rmse:3.61400
# [664]	validation_0-rmse:3.61393
# [665]	validation_0-rmse:3.61391
# [666]	validation_0-rmse:3.61384
# [667]	validation_0-rmse:3.61364
# [668]	validation_0-rmse:3.61350
# [669]	validation_0-rmse:3.61357
# [670]	validation_0-rmse:3.61354
# [671]	validation_0-rmse:3.61352
# [672]	validation_0-rmse:3.61337
# [673]	validation_0-rmse:3.61335
# [674]	validation_0-rmse:3.61327
# [675]	validation_0-rmse:3.61319
# [676]	validation_0-rmse:3.61315
# [677]	validation_0-rmse:3.61324
# [678]	validation_0-rmse:3.61337
# [679]	validation_0-rmse:3.61334
# [680]	validation_0-rmse:3.61348
# [681]	validation_0-rmse:3.61348
# [682]	validation_0-rmse:3.61339
# [683]	validation_0-rmse:3.61328
# [684]	validation_0-rmse:3.61322
# [685]	validation_0-rmse:3.61320
# [686]	validation_0-rmse:3.61318
# [687]	validation_0-rmse:3.61309
# [688]	validation_0-rmse:3.61308
# [689]	validation_0-rmse:3.61304
# [690]	validation_0-rmse:3.61291
# [691]	validation_0-rmse:3.61287
# [692]	validation_0-rmse:3.61286
# [693]	validation_0-rmse:3.61279
# [694]	validation_0-rmse:3.61284
# [695]	validation_0-rmse:3.61288
# [696]	validation_0-rmse:3.61271
# [697]	validation_0-rmse:3.61272
# [698]	validation_0-rmse:3.61276
# [699]	validation_0-rmse:3.61275
# [700]	validation_0-rmse:3.61273
# [701]	validation_0-rmse:3.61276
# [702]	validation_0-rmse:3.61274
# [703]	validation_0-rmse:3.61269
# [704]	validation_0-rmse:3.61269
# [705]	validation_0-rmse:3.61274
# [706]	validation_0-rmse:3.61271
# [707]	validation_0-rmse:3.61263
# [708]	validation_0-rmse:3.61259
# [709]	validation_0-rmse:3.61257
# [710]	validation_0-rmse:3.61251
# [711]	validation_0-rmse:3.61253
# [712]	validation_0-rmse:3.61253
# [713]	validation_0-rmse:3.61248
# [714]	validation_0-rmse:3.61249
# [715]	validation_0-rmse:3.61239
# [716]	validation_0-rmse:3.61250
# [717]	validation_0-rmse:3.61272
# [718]	validation_0-rmse:3.61276
# [719]	validation_0-rmse:3.61280
# [720]	validation_0-rmse:3.61280
# [721]	validation_0-rmse:3.61278
# [722]	validation_0-rmse:3.61262
# [723]	validation_0-rmse:3.61251
# [724]	validation_0-rmse:3.61274
# [725]	validation_0-rmse:3.61271
# [726]	validation_0-rmse:3.61273
# [727]	validation_0-rmse:3.61271
# [728]	validation_0-rmse:3.61272
# [729]	validation_0-rmse:3.61248
# [730]	validation_0-rmse:3.61248
# [731]	validation_0-rmse:3.61250
# [732]	validation_0-rmse:3.61251
# [733]	validation_0-rmse:3.61275
# [734]	validation_0-rmse:3.61247
# [735]	validation_0-rmse:3.61257
# [736]	validation_0-rmse:3.61247
# [737]	validation_0-rmse:3.61244
# [738]	validation_0-rmse:3.61247
# [739]	validation_0-rmse:3.61264
# [740]	validation_0-rmse:3.61271
# [741]	validation_0-rmse:3.61271
# [742]	validation_0-rmse:3.61266
# [743]	validation_0-rmse:3.61261
# [744]	validation_0-rmse:3.61265
# [745]	validation_0-rmse:3.61263
# [746]	validation_0-rmse:3.61256
# [747]	validation_0-rmse:3.61252
# [748]	validation_0-rmse:3.61242
# [749]	validation_0-rmse:3.61247
# [750]	validation_0-rmse:3.61245
# [751]	validation_0-rmse:3.61248
# [752]	validation_0-rmse:3.61253
# [753]	validation_0-rmse:3.61257
# [754]	validation_0-rmse:3.61267
# [755]	validation_0-rmse:3.61269
# [756]	validation_0-rmse:3.61245
# [757]	validation_0-rmse:3.61253
# [758]	validation_0-rmse:3.61243
# [759]	validation_0-rmse:3.61244
# [760]	validation_0-rmse:3.61223
# [761]	validation_0-rmse:3.61207
# [762]	validation_0-rmse:3.61201
# [763]	validation_0-rmse:3.61235
# [764]	validation_0-rmse:3.61221
# [765]	validation_0-rmse:3.61212
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Did not meet early stopping. Best iteration is:
# [995]	valid_0's rmse: 3.59351
# [LightGBM] [Warning] early_stopping_round is set=50, early_stopping_rounds=50 will be ignored. Current value: early_stopping_round=50
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.092837 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3351
# [LightGBM] [Info] Number of data points in the train set: 597727, number of used features: 34
# [LightGBM] [Warning] early_stopping_round is set=50, early_stopping_rounds=50 will be ignored. Current value: early_stopping_round=50
# [LightGBM] [Info] Start training from score 88.363905
# Training until validation scores don't improve for 50 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Did not meet early stopping. Best iteration is:
# [999]	valid_0's rmse: 3.5636
# CV RMSLE: 0.06247 (+/- 0.00064)
# Validation RMSLE: 0.06088
#
# Training Random_Forest...
# CV RMSLE: 0.06229 (+/- 0.00084)
# Validation RMSLE: 0.06084
#
# Training Extra_Trees...
# CV RMSLE: 0.07203 (+/- 0.00078)
# Validation RMSLE: 0.07125
#
# Training Gradient_Boosting...
# CV RMSLE: 0.06309 (+/- 0.00074)
# Validation RMSLE: 0.06178

# %%
# Create advanced ensemble
def create_weighted_ensemble(models_dict, X_train, y_train, X_val, y_val):
    """Create weighted ensemble based on validation performance"""
    
    # Get validation predictions for each model
    val_predictions = {}
    weights = {}
    
    total_inverse_error = 0
    for name, model_info in models_dict.items():
        model = model_info['model']
        val_pred = model.predict(X_val)
        val_predictions[name] = val_pred
        
        # Weight inversely proportional to validation error
        error = model_info['val_rmsle']
        weight = 1 / (error + 1e-8)
        weights[name] = weight
        total_inverse_error += weight
    
    # Normalize weights
    for name in weights:
        weights[name] /= total_inverse_error
    
    print("Ensemble weights:")
    for name, weight in weights.items():
        print(f"{name}: {weight:.4f}")
    
    # Create weighted ensemble predictions
    ensemble_val_pred = np.zeros(len(X_val))
    for name, pred in val_predictions.items():
        ensemble_val_pred += weights[name] * pred
    
    ensemble_rmsle = rmsle(y_val, ensemble_val_pred)
    print(f"\nEnsemble Validation RMSLE: {ensemble_rmsle:.5f}")
    
    return weights, ensemble_rmsle

# %%
# Create ensemble
ensemble_weights, ensemble_score = create_weighted_ensemble(model_results, X_train, y_train, X_val, y_val)
# Out:
# Ensemble weights:
# XGBoost: 0.2048
# LightGBM: 0.2070
# Random_Forest: 0.2072
# Extra_Trees: 0.1769
# Gradient_Boosting: 0.2040
#
# Ensemble Validation RMSLE: 0.06029

# %%
# Retrain on full dataset
print("\nRetraining models on full dataset...")
X_full = pd.concat([X_train, X_val])
y_full = pd.concat([y_train, y_val])

final_models = {}
for name, model_info in model_results.items():
    model = model_info['model']
    
    if name == 'XGBoost':
        params = model.get_params()
        # Remove early stopping for full dataset training
        params['early_stopping_rounds'] = None
        fresh_model = xgb.XGBRegressor(**params)

    elif name == 'LightGBM':
        params = model.get_params()
        # Remove early stopping for full dataset training
        params['early_stopping_rounds'] = None
        fresh_model = lgb.LGBMRegressor(**params)

    else:
        fresh_model = model.__class__(**model.get_params())
    
    fresh_model.fit(X_full, y_full)
    final_models[name] = fresh_model
    print(f"Retrained {name} on full dataset")
# Out:
# Retraining models on full dataset...
# Retrained XGBoost on full dataset
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.114299 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3351
# [LightGBM] [Info] Number of data points in the train set: 747159, number of used features: 34
# [LightGBM] [Info] Start training from score 88.362592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Retrained LightGBM on full dataset
# Retrained Random_Forest on full dataset
# Retrained Extra_Trees on full dataset
# Retrained Gradient_Boosting on full dataset

# %%
# Generate predictions
print("\nGenerating test predictions...")
test_scaled = pd.DataFrame(scaler.transform(test_processed), 
                          columns=test_processed.columns, 
                          index=test_processed.index)

print(f"Test data shape for prediction: {test_scaled.shape}")
print(f"Training features shape: {X_scaled.shape}")
# Out:
# Generating test predictions...
# Test data shape for prediction: (250000, 34)
# Training features shape: (747159, 34)

# %%
# Verify column alignment
if list(test_scaled.columns) != list(X_scaled.columns):
    print("WARNING: Column mismatch between train and test!")
    print(f"Train columns: {len(X_scaled.columns)}")
    print(f"Test columns: {len(test_scaled.columns)}")
    # Ensure test has same columns as train in same order
    test_scaled = test_scaled.reindex(columns=X_scaled.columns, fill_value=0)

# %%
# Individual model predictions
test_predictions = {}
for name, model in final_models.items():
    pred = model.predict(test_scaled)
    test_predictions[name] = pred

# %%
# Ensemble prediction
ensemble_pred = np.zeros(len(test_scaled))
for name, pred in test_predictions.items():
    ensemble_pred += ensemble_weights[name] * pred

# Ensure non-negative predictions
ensemble_pred = np.maximum(ensemble_pred, 0)

# %%
# Create submission
submission = pd.DataFrame({
    'id': test_df['id'],
    'Calories': ensemble_pred
})

# Save submission
submission.to_csv('submission_improved.csv', index=False)
print(f"\nSubmission saved! Shape: {submission.shape}")
print(f"Prediction range: {ensemble_pred.min():.2f} to {ensemble_pred.max():.2f}")
print(f"Mean prediction: {ensemble_pred.mean():.2f}")
# Out:
# Submission saved! Shape: (250000, 2)
# Prediction range: 1.03 to 290.59
# Mean prediction: 88.24

# %%
# Feature importance analysis
def analyze_feature_importance(models_dict):
    """Analyze feature importance across models"""
    importance_data = {}
    
    for name, model in models_dict.items():
        if hasattr(model, 'feature_importances_'):
            importance_data[name] = model.feature_importances_
    
    if importance_data:
        importance_df = pd.DataFrame(importance_data, index=X.columns)
        importance_df['Average'] = importance_df.mean(axis=1)
        importance_df = importance_df.sort_values('Average', ascending=False)
        
        print("\nTop 20 most important features:")
        print(importance_df['Average'].head(20))
        
        return importance_df
    
    return None

feature_importance = analyze_feature_importance(final_models)
# Out:
# Top 20 most important features:
# HR_Duration            762.319614
# Heart_Rate             619.222325
# HR_Intensity           599.021076
# Age_Weight             362.402814
# HR_Reserve             350.205904
# BMI_Duration           311.628954
# BMR                    292.200621
# BMR_Duration           272.221913
# Duration               264.470960
# Weight_Duration        244.821650
# Age                    228.801584
# Weight                 222.400390
# BMI                    201.000098
# Body_Temp              193.020137
# Sex_male               187.602701
# Weight_Height_Ratio    184.000277
# Height                 163.600157
# HR_Squared             125.223062
# Duration_Squared        60.955942
# Temp_Deviation          45.415912
# Name: Average, dtype: float64

# %%
print("\n" + "="*50)
print("SUMMARY")
print("="*50)
print(f"Best single model: {min(model_results.items(), key=lambda x: x[1]['val_rmsle'])[0]}")
print(f"Best single model RMSLE: {min(model_results.values(), key=lambda x: x['val_rmsle'])['val_rmsle']:.5f}")
print(f"Ensemble RMSLE: {ensemble_score:.5f}")
print("Submission file: submission_improved.csv")
# Out:
# ==================================================
# SUMMARY
# ==================================================
# Best single model: Random_Forest
# Best single model RMSLE: 0.06084
# Ensemble RMSLE: 0.06029
# Submission file: submission_improved.csv
